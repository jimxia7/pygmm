# %%
import pygmm

# %matplotlib inline

# %%
scenario = pygmm.Scenario(mag=7, dist_rup=20, site_cond="C", mechanism = "NS")

# %%
TBA03 = pygmm.TravasarouBrayAbrahamson2003(scenario)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 IA = pygmm.TravasarouBrayAbrahamson2003(scenario)
#
# AttributeError: module 'pygmm' has no attribute 'TravasarouBrayAbrahamson2003'

# %%
Ia = TBA03.Arias_Intensity

# %%
Ia_total_error = TBA03.std_err
