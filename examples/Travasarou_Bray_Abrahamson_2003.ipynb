# %%
import pygmm

# %matplotlib inline

# %%
scenario = pygmm.Scenario(mag=7, dist_rup=20, site_cond="C", mechanism = "NS")

# %%
TBA03 = pygmm.TravasarouBrayAbrahamson2003(scenario)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 TBA03 = pygmm.TravasarouBrayAbrahamson2003(scenario)
#
# File c:\Users\jimxi\anaconda3\envs\SRA\Lib\site-packages\pygmm\Travasarou_Bray_Abrahamson_2003.py:32, in TravasarouBrayAbrahamson2003.__init__(self, scenario)
#      31 def __init__(self, scenario:model.Scenario):
# ---> 32     super().__init__(scenario)
#      35     # total druation
#      36     self._ln_IA = self._calc_ln_Arias_Intensity()
#
# File c:\Users\jimxi\anaconda3\envs\SRA\Lib\site-packages\pygmm\model.py:171, in Model.__init__(self, *args, **kwargs)
#     166 # Select the used parameters and check them against the recommended
#     167 # values
#     168 self._scenario = Scenario(
#     169     **{p.name: scenario.get(p.name, None) for p in self.PARAMS}
#     170 )
# --> 171 self._check_inputs()
#
# ...

# %%
Ia = TBA03.Arias_Intensity

# %%
Ia_total_error = TBA03.std_err
